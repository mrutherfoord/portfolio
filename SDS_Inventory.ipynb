# %% [markdown]
# <a href="https://colab.research.google.com/github/mrutherfoord/portfolio/blob/master/SDS_Inventory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # SDS Inventory
# This is a project where I was able to use Python at my regular job.
#
# Companies whose employees work with chemicals are required to keep Safety Data Sheets available for anyone to view. These sheets contain important information like first aid measures and toxicological information if a person is exposed to a product.
#
# In addition to gathering and organizing the SDS sheets, Risk Management informed us that we also needed to provide a spreadsheet that listed each manufacturer and product along with every CAS number, a unique chemical identifier given to every chemical. CAS numbers are comprised of three parts and range between five and ten digits in length. Products without CAS numbers did not need to be included.
#
# Going through each of the roughly 1200 SDS sheets in four departments in order to find and record every chemical would have taken weeks to do manually, so I wrote this program to pull out the CAS numbers from our documents and format them the way Risk Management directed.
#
# All of the SDS sheets were in PDF form, so I first coverted them to excel sheets using an online converter.
#
# This notebook shows this process for one of the departments.

# %%
# import modules
import os
import re
import glob
import pandas as pd
import csv
import numpy as np

# %%
def process_excel(folder_path):
    """Consolidating excel files with multiple sheets into single excel files"""

    excel_files = glob.glob(folder_path)
            
    for excel in excel_files:
        sheets_dict = pd.read_excel(excel, sheet_name=None, header=None)
        out = excel.split('.')[0]+'.csv'
        full_table = pd.DataFrame()
    
        for name, sheet in sheets_dict.items():
        # replace NaN values with spaces and make everything lowercase
            full_table = full_table.append(sheet)
        full_table = full_table.fillna('').astype(str).apply(lambda x: x.str.lower())
  
        for col in full_table:
        # replace any non-ASCii characters with space
            full_table[col].replace({r'[^\x00-\x7F]+':' '}, regex=True, inplace=True)
        full_table.reset_index(inplace=True, drop=True)
    
        # export to csv
        full_table.to_csv(out, index=False, encoding='utf-8')

# %%
# path to convert xlsx to csv 
my_path = 'C:/Users/mturn/Documents/MSDS458/SDS/Light_Shop_SDS_xlsx/*/*.xlsx'

# %%
def remove_excel(folder_path):
    """Remove excel files while keeping CSV"""
    for directory, subdir, filename in os.walk(folder_path):
        for file in filename:
            if file.endswith(".xlsx"):
                os.remove(os.path.join(directory, file))

# %%
def find_cas_numbers(folder_path):
    """Get manufacturer, product, and CAS numbers"""
    global cas_numbers
    cas_numbers = {}
    global manufacturer
    manufacturer = []
    for directory, subdir, filename in os.walk(folder_path):
        for file in filename:
            file_name = file.split('.')[0]
            sds_file = os.path.join(directory, file)
            dir_name = os.path.basename(os.path.dirname(sds_file))
            manufacturer.append(dir_name)
            with open(sds_file, 'r') as f:
                text = f.read()
                result = set(re.findall('[1-9]{1}[0-9]{1,5}-\d{2}-\d', text))
                cas_numbers.update({file_name:result})
    return

# %%
# path to organize csv
my_path = 'C:/Users/mturn/Documents/MSDS458/SDS/Light_Shop_SDS_xlsx/'

# %%
remove_excel(my_path)

# %%
find_cas_numbers(my_path)

# %%
# Make a dataframe from cas_number dictionary
sds_dataframe = pd.DataFrame.from_dict(cas_numbers, orient='index')

# %%
sds_dataframe
# Out:
#                                                             0            1   \
# desktop                                                   None         None
# Ad-Tech_962_Black_Glue_Stick                          557-05-1   24937-78-8
# Graphite_Powder_Extra_Fine                          14808-60-7         None
# Lock Ease_Graphited_Lock_Fluid                       7782-42-5      71-43-2
# Solder_Paste_Flux                                         None         None
# Circuit_Writer_Conductive_Silver_Ink                 7440-22-4     106-65-0
# High_Performance_Fluid                                    None         None
# Deco_Art_Dazzling_Metallics_All_Colors               7732-18-5      57-55-6
# Energizer_Batteries                                  7782-42-5    7440-66-6
# Goo_Gone                                             8028-48-6   64742-47-8
# Loctite_Clear_Silicone_Sealant                       2017-03-2   17689-77-9
# Loctite_Epoxy_Extra_Time_Resin                       2014-09-1         None
# Loctite_Epoxy_Quickset_Part_A                        2014-09-1         None
# Loctite_Threadlocker_Blue_242                          81-07-2      57-55-6
# Alkaline_Button_Cell_Battery_AG13                    7440-66-6    2015-07-1
# Atmospheres_HQ_Light_Enhancement_Fluid                 57-55-6     112-27-6
# Permatex_Clear_RTV_Silicone                          7631-86-9         None
# Solid_Lead-Free_Alloy_Solder_Wire                    7440-69-9    7440-22-4
# Look_Solutions_Fog_Fluid_&_Haze_Fluid                 110-98-5    7732-18-5
# Powerex_AA_Rechargeable_Batteries                    7440-66-6    7439-96-5
# MDG_Natural_Fluid                                    2009-11-1    8042-47-5
# Sharpie_Accent_Highlighters_All_Colors                111-46-6      57-55-6
# Sharpie_Markers_All_Colors_and_Sizes                   71-36-3     123-42-2
# UniPaint_Markers_All_Colors_and_Sizes                7440-50-8    1330-20-7
# Duracell_Alkaline_Batteries                          7782-42-5    7440-66-6
# Febreze_Set_&_Refresh_Rain                          16409-43-1   57378-68-4
# Lysol_III_Disinfectant_Spray_All_Scents                74-98-6     777-99-6
# Lithium_Ion_Battery_Cell_For_Use_With_Anton-Bau...   7782-42-5  182442-95-1
# Windex_Original_Glass_Cleaner                             None         None
# Nickel_Metal_Hydride_Batteries                       7440-66-6    7439-96-5
# Office_Depot_Compressed_Air_Duster                     75-37-6         None
# Set_XP_High_Strength_Epoxy_Adhesive                 14808-60-7    1344-28-1
# Gorilla_Hot_Glue_Clear                                    None         None
# Gorilla_Super_Glue                                   7085-85-0         None
# Sealed_Lead_Acid_Batteries                           9003-55-8    7440-38-2
# XT_Power_Lithium_Polymer_Battery                    12057-24-8   24937-79-9
# WD-40_Multi-Use_Product_Aerosol                     64742-71-8   64742-65-0
# Goof_Off_2                                            111-76-2     770-35-4
#
#                                                             2            3   \
# desktop                                                   None         None
# Ad-Tech_962_Black_Glue_Stick                         9002-88-4   64742-16-1
# Graphite_Powder_Extra_Fine                                None         None
# Lock Ease_Graphited_Lock_Fluid                      64742-82-1      91-20-3
# Solder_Paste_Flux                                         None         None
# Circuit_Writer_Conductive_Silver_Ink                  627-93-0    1119-40-0
# High_Performance_Fluid                                    None         None
# Deco_Art_Dazzling_Metallics_All_Colors              12001-26-2   28205-96-1
# Energizer_Batteries                                  1310-58-3   65997-19-5
# Goo_Gone                                             5989-27-5         None
# Loctite_Clear_Silicone_Sealant                       7631-86-9    4253-34-3
# Loctite_Epoxy_Extra_Time_Resin                            None         None
# Loctite_Epoxy_Quickset_Part_A                             None         None
# Loctite_Threadlocker_Blue_242                          80-15-9      98-82-8
# Alkaline_Button_Cell_Battery_AG13                    7732-18-5    9003-53-6
# Atmospheres_HQ_Light_Enhancement_Fluid                    None         None
# Permatex_Clear_RTV_Silicone                               None         None
# Solid_Lead-Free_Alloy_Solder_Wire                    7440-50-8    7440-31-5
# Look_Solutions_Fog_Fluid_&_Haze_Fluid                  57-55-6     112-27-6
# Powerex_AA_Rechargeable_Batteries                    7429-90-5    1310-73-2
# MDG_Natural_Fluid                                         None         None
# Sharpie_Accent_Highlighters_All_Colors              25322-68-3      56-81-5
# Sharpie_Markers_All_Colors_and_Sizes                   64-17-5      71-23-8
# UniPaint_Markers_All_Colors_and_Sizes                  78-83-1    7440-66-6
# Duracell_Alkaline_Batteries                            41-58-0    7440-44-0
# Febreze_Set_&_Refresh_Rain                           2060-12-0  476332-65-7
# Lysol_III_Disinfectant_Spray_All_Scents                64-17-5     106-97-8
# Lithium_Ion_Battery_Cell_For_Use_With_Anton-Bau...    799-24-4     799-23-2
# Windex_Original_Glass_Cleaner                             None         None
# Nickel_Metal_Hydride_Batteries                       7429-90-5    1310-73-2
# Office_Depot_Compressed_Air_Duster                        None         None
# Set_XP_High_Strength_Epoxy_Adhesive                  2426-08-0      69-00-0
# Gorilla_Hot_Glue_Clear                                    None         None
# Gorilla_Super_Glue                                        None         None
# Sealed_Lead_Acid_Batteries                           9003-56-9    7664-93-9
# XT_Power_Lithium_Polymer_Battery                     9003-07-0    7440-50-8
# WD-40_Multi-Use_Product_Aerosol                       124-38-9   64742-47-8
# Goof_Off_2                                            100-51-6     112-34-5
#
#                                                             4           5   \
# desktop                                                   None        None
# Ad-Tech_962_Black_Glue_Stick                              None        None
# Graphite_Powder_Extra_Fine                                None        None
# Lock Ease_Graphited_Lock_Fluid                       2057-10-0   8052-41-3
# Solder_Paste_Flux                                         None        None
# Circuit_Writer_Conductive_Silver_Ink                      None        None
# High_Performance_Fluid                                    None        None
# Deco_Art_Dazzling_Metallics_All_Colors                    None        None
# Energizer_Batteries                                  1313-13-9        None
# Goo_Gone                                                  None        None
# Loctite_Clear_Silicone_Sealant                      64742-46-7     64-19-7
# Loctite_Epoxy_Extra_Time_Resin                            None        None
# Loctite_Epoxy_Quickset_Part_A                             None        None
# Loctite_Threadlocker_Blue_242                        9004-96-0   2081-07-0
# Alkaline_Button_Cell_Battery_AG13                    1310-58-3   7439-89-6
# Atmospheres_HQ_Light_Enhancement_Fluid                    None        None
# Permatex_Clear_RTV_Silicone                               None        None
# Solid_Lead-Free_Alloy_Solder_Wire                    7440-36-0        None
# Look_Solutions_Fog_Fluid_&_Haze_Fluid                     None        None
# Powerex_AA_Rechargeable_Batteries                    1310-58-3   7439-89-6
# MDG_Natural_Fluid                                         None        None
# Sharpie_Accent_Highlighters_All_Colors                    None        None
# Sharpie_Markers_All_Colors_and_Sizes                      None        None
# UniPaint_Markers_All_Colors_and_Sizes                     None        None
# Duracell_Alkaline_Batteries                          1310-58-3   1313-13-9
# Febreze_Set_&_Refresh_Rain                            112-45-8  81786-74-5
# Lysol_III_Disinfectant_Spray_All_Scents                   None        None
# Lithium_Ion_Battery_Cell_For_Use_With_Anton-Bau...  12190-79-3   7440-44-0
# Windex_Original_Glass_Cleaner                             None        None
# Nickel_Metal_Hydride_Batteries                       1310-58-3   7439-89-6
# Office_Depot_Compressed_Air_Duster                        None        None
# Set_XP_High_Strength_Epoxy_Adhesive                    74-00-8     39-00-7
# Gorilla_Hot_Glue_Clear                                    None        None
# Gorilla_Super_Glue                                        None        None
# Sealed_Lead_Acid_Batteries                           7439-92-1   9003-07-0
# XT_Power_Lithium_Polymer_Battery                      133-86-4   7429-50-5
# WD-40_Multi-Use_Product_Aerosol                     64742-56-9  64742-54-7
# Goof_Off_2                                                None        None
#
#                                                              6           7   \
# desktop                                                    None        None
# Ad-Tech_962_Black_Glue_Stick                               None        None
# Graphite_Powder_Extra_Fine                                 None        None
# Lock Ease_Graphited_Lock_Fluid                        1305-62-0    506-12-7
# Solder_Paste_Flux                                          None        None
# Circuit_Writer_Conductive_Silver_Ink                       None        None
# High_Performance_Fluid                                     None        None
# Deco_Art_Dazzling_Metallics_All_Colors                     None        None
# Energizer_Batteries                                        None        None
# Goo_Gone                                                   None        None
# Loctite_Clear_Silicone_Sealant                             None        None
# Loctite_Epoxy_Extra_Time_Resin                             None        None
# Loctite_Epoxy_Quickset_Part_A                              None        None
# Loctite_Threadlocker_Blue_242                       112945-52-5  13463-67-7
# Alkaline_Button_Cell_Battery_AG13                     1313-13-9   9004-34-6
# Atmospheres_HQ_Light_Enhancement_Fluid                     None        None
# Permatex_Clear_RTV_Silicone                                None        None
# Solid_Lead-Free_Alloy_Solder_Wire                          None        None
# Look_Solutions_Fog_Fluid_&_Haze_Fluid                      None        None
# Powerex_AA_Rechargeable_Batteries                     7440-02-0   1310-65-2
# MDG_Natural_Fluid                                          None        None
# Sharpie_Accent_Highlighters_All_Colors                     None        None
# Sharpie_Markers_All_Colors_and_Sizes                       None        None
# UniPaint_Markers_All_Colors_and_Sizes                      None        None
# Duracell_Alkaline_Batteries                                None        None
# Febreze_Set_&_Refresh_Rain                              97-54-1   8000-41-7
# Lysol_III_Disinfectant_Spray_All_Scents                    None        None
# Lithium_Ion_Battery_Cell_For_Use_With_Anton-Bau...    7429-90-5  12057-17-9
# Windex_Original_Glass_Cleaner                              None        None
# Nickel_Metal_Hydride_Batteries                        7440-02-0   1310-65-2
# Office_Depot_Compressed_Air_Duster                         None        None
# Set_XP_High_Strength_Epoxy_Adhesive                     90-72-2  68953-36-6
# Gorilla_Hot_Glue_Clear                                     None        None
# Gorilla_Super_Glue                                         None        None
# Sealed_Lead_Acid_Batteries                            9003-53-6   7440-31-5
# XT_Power_Lithium_Polymer_Battery                      7440-02-0  21340-40-3
# WD-40_Multi-Use_Product_Aerosol                      64742-53-6        None
# Goof_Off_2                                                 None        None
#
#                                                             8          9   \
# desktop                                                   None       None
# Ad-Tech_962_Black_Glue_Stick                              None       None
# Graphite_Powder_Extra_Fine                                None       None
# Lock Ease_Graphited_Lock_Fluid                         57-11-4   100-41-4
# Solder_Paste_Flux                                         None       None
# Circuit_Writer_Conductive_Silver_Ink                      None       None
# High_Performance_Fluid                                    None       None
# Deco_Art_Dazzling_Metallics_All_Colors                    None       None
# Energizer_Batteries                                       None       None
# Goo_Gone                                                  None       None
# Loctite_Clear_Silicone_Sealant                            None       None
# Loctite_Epoxy_Extra_Time_Resin                            None       None
# Loctite_Epoxy_Quickset_Part_A                             None       None
# Loctite_Threadlocker_Blue_242                        2018-01-1       None
# Alkaline_Button_Cell_Battery_AG13                         None       None
# Atmospheres_HQ_Light_Enhancement_Fluid                    None       None
# Permatex_Clear_RTV_Silicone                               None       None
# Solid_Lead-Free_Alloy_Solder_Wire                         None       None
# Look_Solutions_Fog_Fluid_&_Haze_Fluid                     None       None
# Powerex_AA_Rechargeable_Batteries                    7440-48-4  1333-86-4
# MDG_Natural_Fluid                                         None       None
# Sharpie_Accent_Highlighters_All_Colors                    None       None
# Sharpie_Markers_All_Colors_and_Sizes                      None       None
# UniPaint_Markers_All_Colors_and_Sizes                     None       None
# Duracell_Alkaline_Batteries                               None       None
# Febreze_Set_&_Refresh_Rain                          32210-23-4  5989-27-5
# Lysol_III_Disinfectant_Spray_All_Scents                   None       None
# Lithium_Ion_Battery_Cell_For_Use_With_Anton-Bau...   7440-50-8   799-23-3
# Windex_Original_Glass_Cleaner                             None       None
# Nickel_Metal_Hydride_Batteries                       7440-48-4  1333-86-4
# Office_Depot_Compressed_Air_Duster                        None       None
# Set_XP_High_Strength_Epoxy_Adhesive                    71-36-3    60-00-0
# Gorilla_Hot_Glue_Clear                                    None       None
# Gorilla_Super_Glue                                        None       None
# Sealed_Lead_Acid_Batteries                           9003-54-7  7440-36-0
# XT_Power_Lithium_Polymer_Battery                     1308-04-9       None
# WD-40_Multi-Use_Product_Aerosol                           None       None
# Goof_Off_2                                                None       None
#
#                                                     ...        19          20  \
# desktop                                             ...      None        None
# Ad-Tech_962_Black_Glue_Stick                        ...      None        None
# Graphite_Powder_Extra_Fine                          ...      None        None
# Lock Ease_Graphited_Lock_Fluid                      ...      None        None
# Solder_Paste_Flux                                   ...      None        None
# Circuit_Writer_Conductive_Silver_Ink                ...      None        None
# High_Performance_Fluid                              ...      None        None
# Deco_Art_Dazzling_Metallics_All_Colors              ...      None        None
# Energizer_Batteries                                 ...      None        None
# Goo_Gone                                            ...      None        None
# Loctite_Clear_Silicone_Sealant                      ...      None        None
# Loctite_Epoxy_Extra_Time_Resin                      ...      None        None
# Loctite_Epoxy_Quickset_Part_A                       ...      None        None
# Loctite_Threadlocker_Blue_242                       ...      None        None
# Alkaline_Button_Cell_Battery_AG13                   ...      None        None
# Atmospheres_HQ_Light_Enhancement_Fluid              ...      None        None
# Permatex_Clear_RTV_Silicone                         ...      None        None
# Solid_Lead-Free_Alloy_Solder_Wire                   ...      None        None
# Look_Solutions_Fog_Fluid_&_Haze_Fluid               ...      None        None
# Powerex_AA_Rechargeable_Batteries                   ...      None        None
# MDG_Natural_Fluid                                   ...      None        None
# Sharpie_Accent_Highlighters_All_Colors              ...      None        None
# Sharpie_Markers_All_Colors_and_Sizes                ...      None        None
# UniPaint_Markers_All_Colors_and_Sizes               ...      None        None
# Duracell_Alkaline_Batteries                         ...      None        None
# Febreze_Set_&_Refresh_Rain                          ...  112-54-9  68039-49-6
# Lysol_III_Disinfectant_Spray_All_Scents             ...      None        None
# Lithium_Ion_Battery_Cell_For_Use_With_Anton-Bau...  ...      None        None
# Windex_Original_Glass_Cleaner                       ...      None        None
# Nickel_Metal_Hydride_Batteries                      ...      None        None
# Office_Depot_Compressed_Air_Duster                  ...      None        None
# Set_XP_High_Strength_Epoxy_Adhesive                 ...      None        None
# Gorilla_Hot_Glue_Clear                              ...      None        None
# Gorilla_Super_Glue                                  ...      None        None
# Sealed_Lead_Acid_Batteries                          ...      None        None
# XT_Power_Lithium_Polymer_Battery                    ...      None        None
# WD-40_Multi-Use_Product_Aerosol                     ...      None        None
# Goof_Off_2                                          ...      None        None
#
#                                                             21        22  \
# desktop                                                   None      None
# Ad-Tech_962_Black_Glue_Stick                              None      None
# Graphite_Powder_Extra_Fine                                None      None
# Lock Ease_Graphited_Lock_Fluid                            None      None
# Solder_Paste_Flux                                         None      None
# Circuit_Writer_Conductive_Silver_Ink                      None      None
# High_Performance_Fluid                                    None      None
# Deco_Art_Dazzling_Metallics_All_Colors                    None      None
# Energizer_Batteries                                       None      None
# Goo_Gone                                                  None      None
# Loctite_Clear_Silicone_Sealant                            None      None
# Loctite_Epoxy_Extra_Time_Resin                            None      None
# Loctite_Epoxy_Quickset_Part_A                             None      None
# Loctite_Threadlocker_Blue_242                             None      None
# Alkaline_Button_Cell_Battery_AG13                         None      None
# Atmospheres_HQ_Light_Enhancement_Fluid                    None      None
# Permatex_Clear_RTV_Silicone                               None      None
# Solid_Lead-Free_Alloy_Solder_Wire                         None      None
# Look_Solutions_Fog_Fluid_&_Haze_Fluid                     None      None
# Powerex_AA_Rechargeable_Batteries                         None      None
# MDG_Natural_Fluid                                         None      None
# Sharpie_Accent_Highlighters_All_Colors                    None      None
# Sharpie_Markers_All_Colors_and_Sizes                      None      None
# UniPaint_Markers_All_Colors_and_Sizes                     None      None
# Duracell_Alkaline_Batteries                               None      None
# Febreze_Set_&_Refresh_Rain                          25265-71-8  112-31-2
# Lysol_III_Disinfectant_Spray_All_Scents                   None      None
# Lithium_Ion_Battery_Cell_For_Use_With_Anton-Bau...        None      None
# Windex_Original_Glass_Cleaner                             None      None
# Nickel_Metal_Hydride_Batteries                            None      None
# Office_Depot_Compressed_Air_Duster                        None      None
# Set_XP_High_Strength_Epoxy_Adhesive                       None      None
# Gorilla_Hot_Glue_Clear                                    None      None
# Gorilla_Super_Glue                                        None      None
# Sealed_Lead_Acid_Batteries                                None      None
# XT_Power_Lithium_Polymer_Battery                          None      None
# WD-40_Multi-Use_Product_Aerosol                           None      None
# Goof_Off_2                                                None      None
#
#                                                           23       24  \
# desktop                                                 None     None
# Ad-Tech_962_Black_Glue_Stick                            None     None
# Graphite_Powder_Extra_Fine                              None     None
# Lock Ease_Graphited_Lock_Fluid                          None     None
# Solder_Paste_Flux                                       None     None
# Circuit_Writer_Conductive_Silver_Ink                    None     None
# High_Performance_Fluid                                  None     None
# Deco_Art_Dazzling_Metallics_All_Colors                  None     None
# Energizer_Batteries                                     None     None
# Goo_Gone                                                None     None
# Loctite_Clear_Silicone_Sealant                          None     None
# Loctite_Epoxy_Extra_Time_Resin                          None     None
# Loctite_Epoxy_Quickset_Part_A                           None     None
# Loctite_Threadlocker_Blue_242                           None     None
# Alkaline_Button_Cell_Battery_AG13                       None     None
# Atmospheres_HQ_Light_Enhancement_Fluid                  None     None
# Permatex_Clear_RTV_Silicone                             None     None
# Solid_Lead-Free_Alloy_Solder_Wire                       None     None
# Look_Solutions_Fog_Fluid_&_Haze_Fluid                   None     None
# Powerex_AA_Rechargeable_Batteries                       None     None
# MDG_Natural_Fluid                                       None     None
# Sharpie_Accent_Highlighters_All_Colors                  None     None
# Sharpie_Markers_All_Colors_and_Sizes                    None     None
# UniPaint_Markers_All_Colors_and_Sizes                   None     None
# Duracell_Alkaline_Batteries                             None     None
# Febreze_Set_&_Refresh_Rain                          142-19-8  78-70-6
# Lysol_III_Disinfectant_Spray_All_Scents                 None     None
# Lithium_Ion_Battery_Cell_For_Use_With_Anton-Bau...      None     None
# Windex_Original_Glass_Cleaner                           None     None
# Nickel_Metal_Hydride_Batteries                          None     None
# Office_Depot_Compressed_Air_Duster                      None     None
# Set_XP_High_Strength_Epoxy_Adhesive                     None     None
# Gorilla_Hot_Glue_Clear                                  None     None
# Gorilla_Super_Glue                                      None     None
# Sealed_Lead_Acid_Batteries                              None     None
# XT_Power_Lithium_Polymer_Battery                        None     None
# WD-40_Multi-Use_Product_Aerosol                         None     None
# Goof_Off_2                                              None     None
#
#                                                           25        26  \
# desktop                                                 None      None
# Ad-Tech_962_Black_Glue_Stick                            None      None
# Graphite_Powder_Extra_Fine                              None      None
# Lock Ease_Graphited_Lock_Fluid                          None      None
# Solder_Paste_Flux                                       None      None
# Circuit_Writer_Conductive_Silver_Ink                    None      None
# High_Performance_Fluid                                  None      None
# Deco_Art_Dazzling_Metallics_All_Colors                  None      None
# Energizer_Batteries                                     None      None
# Goo_Gone                                                None      None
# Loctite_Clear_Silicone_Sealant                          None      None
# Loctite_Epoxy_Extra_Time_Resin                          None      None
# Loctite_Epoxy_Quickset_Part_A                           None      None
# Loctite_Threadlocker_Blue_242                           None      None
# Alkaline_Button_Cell_Battery_AG13                       None      None
# Atmospheres_HQ_Light_Enhancement_Fluid                  None      None
# Permatex_Clear_RTV_Silicone                             None      None
# Solid_Lead-Free_Alloy_Solder_Wire                       None      None
# Look_Solutions_Fog_Fluid_&_Haze_Fluid                   None      None
# Powerex_AA_Rechargeable_Batteries                       None      None
# MDG_Natural_Fluid                                       None      None
# Sharpie_Accent_Highlighters_All_Colors                  None      None
# Sharpie_Markers_All_Colors_and_Sizes                    None      None
# UniPaint_Markers_All_Colors_and_Sizes                   None      None
# Duracell_Alkaline_Batteries                             None      None
# Febreze_Set_&_Refresh_Rain                          106-25-2  115-95-7
# Lysol_III_Disinfectant_Spray_All_Scents                 None      None
# Lithium_Ion_Battery_Cell_For_Use_With_Anton-Bau...      None      None
# Windex_Original_Glass_Cleaner                           None      None
# Nickel_Metal_Hydride_Batteries                          None      None
# Office_Depot_Compressed_Air_Duster                      None      None
# Set_XP_High_Strength_Epoxy_Adhesive                     None      None
# Gorilla_Hot_Glue_Clear                                  None      None
# Gorilla_Super_Glue                                      None      None
# Sealed_Lead_Acid_Batteries                              None      None
# XT_Power_Lithium_Polymer_Battery                        None      None
# WD-40_Multi-Use_Product_Aerosol                         None      None
# Goof_Off_2                                              None      None
#
#                                                           27       28
# desktop                                                 None     None
# Ad-Tech_962_Black_Glue_Stick                            None     None
# Graphite_Powder_Extra_Fine                              None     None
# Lock Ease_Graphited_Lock_Fluid                          None     None
# Solder_Paste_Flux                                       None     None
# Circuit_Writer_Conductive_Silver_Ink                    None     None
# High_Performance_Fluid                                  None     None
# Deco_Art_Dazzling_Metallics_All_Colors                  None     None
# Energizer_Batteries                                     None     None
# Goo_Gone                                                None     None
# Loctite_Clear_Silicone_Sealant                          None     None
# Loctite_Epoxy_Extra_Time_Resin                          None     None
# Loctite_Epoxy_Quickset_Part_A                           None     None
# Loctite_Threadlocker_Blue_242                           None     None
# Alkaline_Button_Cell_Battery_AG13                       None     None
# Atmospheres_HQ_Light_Enhancement_Fluid                  None     None
# Permatex_Clear_RTV_Silicone                             None     None
# Solid_Lead-Free_Alloy_Solder_Wire                       None     None
# Look_Solutions_Fog_Fluid_&_Haze_Fluid                   None     None
# Powerex_AA_Rechargeable_Batteries                       None     None
# MDG_Natural_Fluid                                       None     None
# Sharpie_Accent_Highlighters_All_Colors                  None     None
# Sharpie_Markers_All_Colors_and_Sizes                    None     None
# UniPaint_Markers_All_Colors_and_Sizes                   None     None
# Duracell_Alkaline_Batteries                             None     None
# Febreze_Set_&_Refresh_Rain                          101-84-8  97-53-0
# Lysol_III_Disinfectant_Spray_All_Scents                 None     None
# Lithium_Ion_Battery_Cell_For_Use_With_Anton-Bau...      None     None
# Windex_Original_Glass_Cleaner                           None     None
# Nickel_Metal_Hydride_Batteries                          None     None
# Office_Depot_Compressed_Air_Duster                      None     None
# Set_XP_High_Strength_Epoxy_Adhesive                     None     None
# Gorilla_Hot_Glue_Clear                                  None     None
# Gorilla_Super_Glue                                      None     None
# Sealed_Lead_Acid_Batteries                              None     None
# XT_Power_Lithium_Polymer_Battery                        None     None
# WD-40_Multi-Use_Product_Aerosol                         None     None
# Goof_Off_2                                              None     None
#
# [38 rows x 29 columns]

# %%
# Combine CAS numbers into one column
sds_dataframe['CAS Numbers'] = sds_dataframe[sds_dataframe.columns[1:]].apply(
    lambda x: ', '.join(x.dropna()), axis=1)

# %%
sds_dataframe
# Out:
#                                                              0            1  \
# desktop                                                   None         None
# Ad-Tech_962_Black_Glue_Stick                          557-05-1   24937-78-8
# Graphite_Powder_Extra_Fine                          14808-60-7         None
# Lock Ease_Graphited_Lock_Fluid                       7782-42-5      71-43-2
# Solder_Paste_Flux                                         None         None
# Circuit_Writer_Conductive_Silver_Ink                 7440-22-4     106-65-0
# High_Performance_Fluid                                    None         None
# Deco_Art_Dazzling_Metallics_All_Colors               7732-18-5      57-55-6
# Energizer_Batteries                                  7782-42-5    7440-66-6
# Goo_Gone                                             8028-48-6   64742-47-8
# Loctite_Clear_Silicone_Sealant                       2017-03-2   17689-77-9
# Loctite_Epoxy_Extra_Time_Resin                       2014-09-1         None
# Loctite_Epoxy_Quickset_Part_A                        2014-09-1         None
# Loctite_Threadlocker_Blue_242                          81-07-2      57-55-6
# Alkaline_Button_Cell_Battery_AG13                    7440-66-6    2015-07-1
# Atmospheres_HQ_Light_Enhancement_Fluid                 57-55-6     112-27-6
# Permatex_Clear_RTV_Silicone                          7631-86-9         None
# Solid_Lead-Free_Alloy_Solder_Wire                    7440-69-9    7440-22-4
# Look_Solutions_Fog_Fluid_&_Haze_Fluid                 110-98-5    7732-18-5
# Powerex_AA_Rechargeable_Batteries                    7440-66-6    7439-96-5
# MDG_Natural_Fluid                                    2009-11-1    8042-47-5
# Sharpie_Accent_Highlighters_All_Colors                111-46-6      57-55-6
# Sharpie_Markers_All_Colors_and_Sizes                   71-36-3     123-42-2
# UniPaint_Markers_All_Colors_and_Sizes                7440-50-8    1330-20-7
# Duracell_Alkaline_Batteries                          7782-42-5    7440-66-6
# Febreze_Set_&_Refresh_Rain                          16409-43-1   57378-68-4
# Lysol_III_Disinfectant_Spray_All_Scents                74-98-6     777-99-6
# Lithium_Ion_Battery_Cell_For_Use_With_Anton-Bau...   7782-42-5  182442-95-1
# Windex_Original_Glass_Cleaner                             None         None
# Nickel_Metal_Hydride_Batteries                       7440-66-6    7439-96-5
# Office_Depot_Compressed_Air_Duster                     75-37-6         None
# Set_XP_High_Strength_Epoxy_Adhesive                 14808-60-7    1344-28-1
# Gorilla_Hot_Glue_Clear                                    None         None
# Gorilla_Super_Glue                                   7085-85-0         None
# Sealed_Lead_Acid_Batteries                           9003-55-8    7440-38-2
# XT_Power_Lithium_Polymer_Battery                    12057-24-8   24937-79-9
# WD-40_Multi-Use_Product_Aerosol                     64742-71-8   64742-65-0
# Goof_Off_2                                            111-76-2     770-35-4
#
#                                                              2            3  \
# desktop                                                   None         None
# Ad-Tech_962_Black_Glue_Stick                         9002-88-4   64742-16-1
# Graphite_Powder_Extra_Fine                                None         None
# Lock Ease_Graphited_Lock_Fluid                      64742-82-1      91-20-3
# Solder_Paste_Flux                                         None         None
# Circuit_Writer_Conductive_Silver_Ink                  627-93-0    1119-40-0
# High_Performance_Fluid                                    None         None
# Deco_Art_Dazzling_Metallics_All_Colors              12001-26-2   28205-96-1
# Energizer_Batteries                                  1310-58-3   65997-19-5
# Goo_Gone                                             5989-27-5         None
# Loctite_Clear_Silicone_Sealant                       7631-86-9    4253-34-3
# Loctite_Epoxy_Extra_Time_Resin                            None         None
# Loctite_Epoxy_Quickset_Part_A                             None         None
# Loctite_Threadlocker_Blue_242                          80-15-9      98-82-8
# Alkaline_Button_Cell_Battery_AG13                    7732-18-5    9003-53-6
# Atmospheres_HQ_Light_Enhancement_Fluid                    None         None
# Permatex_Clear_RTV_Silicone                               None         None
# Solid_Lead-Free_Alloy_Solder_Wire                    7440-50-8    7440-31-5
# Look_Solutions_Fog_Fluid_&_Haze_Fluid                  57-55-6     112-27-6
# Powerex_AA_Rechargeable_Batteries                    7429-90-5    1310-73-2
# MDG_Natural_Fluid                                         None         None
# Sharpie_Accent_Highlighters_All_Colors              25322-68-3      56-81-5
# Sharpie_Markers_All_Colors_and_Sizes                   64-17-5      71-23-8
# UniPaint_Markers_All_Colors_and_Sizes                  78-83-1    7440-66-6
# Duracell_Alkaline_Batteries                            41-58-0    7440-44-0
# Febreze_Set_&_Refresh_Rain                           2060-12-0  476332-65-7
# Lysol_III_Disinfectant_Spray_All_Scents                64-17-5     106-97-8
# Lithium_Ion_Battery_Cell_For_Use_With_Anton-Bau...    799-24-4     799-23-2
# Windex_Original_Glass_Cleaner                             None         None
# Nickel_Metal_Hydride_Batteries                       7429-90-5    1310-73-2
# Office_Depot_Compressed_Air_Duster                        None         None
# Set_XP_High_Strength_Epoxy_Adhesive                  2426-08-0      69-00-0
# Gorilla_Hot_Glue_Clear                                    None         None
# Gorilla_Super_Glue                                        None         None
# Sealed_Lead_Acid_Batteries                           9003-56-9    7664-93-9
# XT_Power_Lithium_Polymer_Battery                     9003-07-0    7440-50-8
# WD-40_Multi-Use_Product_Aerosol                       124-38-9   64742-47-8
# Goof_Off_2                                            100-51-6     112-34-5
#
#                                                              4           5  \
# desktop                                                   None        None
# Ad-Tech_962_Black_Glue_Stick                              None        None
# Graphite_Powder_Extra_Fine                                None        None
# Lock Ease_Graphited_Lock_Fluid                       2057-10-0   8052-41-3
# Solder_Paste_Flux                                         None        None
# Circuit_Writer_Conductive_Silver_Ink                      None        None
# High_Performance_Fluid                                    None        None
# Deco_Art_Dazzling_Metallics_All_Colors                    None        None
# Energizer_Batteries                                  1313-13-9        None
# Goo_Gone                                                  None        None
# Loctite_Clear_Silicone_Sealant                      64742-46-7     64-19-7
# Loctite_Epoxy_Extra_Time_Resin                            None        None
# Loctite_Epoxy_Quickset_Part_A                             None        None
# Loctite_Threadlocker_Blue_242                        9004-96-0   2081-07-0
# Alkaline_Button_Cell_Battery_AG13                    1310-58-3   7439-89-6
# Atmospheres_HQ_Light_Enhancement_Fluid                    None        None
# Permatex_Clear_RTV_Silicone                               None        None
# Solid_Lead-Free_Alloy_Solder_Wire                    7440-36-0        None
# Look_Solutions_Fog_Fluid_&_Haze_Fluid                     None        None
# Powerex_AA_Rechargeable_Batteries                    1310-58-3   7439-89-6
# MDG_Natural_Fluid                                         None        None
# Sharpie_Accent_Highlighters_All_Colors                    None        None
# Sharpie_Markers_All_Colors_and_Sizes                      None        None
# UniPaint_Markers_All_Colors_and_Sizes                     None        None
# Duracell_Alkaline_Batteries                          1310-58-3   1313-13-9
# Febreze_Set_&_Refresh_Rain                            112-45-8  81786-74-5
# Lysol_III_Disinfectant_Spray_All_Scents                   None        None
# Lithium_Ion_Battery_Cell_For_Use_With_Anton-Bau...  12190-79-3   7440-44-0
# Windex_Original_Glass_Cleaner                             None        None
# Nickel_Metal_Hydride_Batteries                       1310-58-3   7439-89-6
# Office_Depot_Compressed_Air_Duster                        None        None
# Set_XP_High_Strength_Epoxy_Adhesive                    74-00-8     39-00-7
# Gorilla_Hot_Glue_Clear                                    None        None
# Gorilla_Super_Glue                                        None        None
# Sealed_Lead_Acid_Batteries                           7439-92-1   9003-07-0
# XT_Power_Lithium_Polymer_Battery                      133-86-4   7429-50-5
# WD-40_Multi-Use_Product_Aerosol                     64742-56-9  64742-54-7
# Goof_Off_2                                                None        None
#
#                                                               6           7  \
# desktop                                                    None        None
# Ad-Tech_962_Black_Glue_Stick                               None        None
# Graphite_Powder_Extra_Fine                                 None        None
# Lock Ease_Graphited_Lock_Fluid                        1305-62-0    506-12-7
# Solder_Paste_Flux                                          None        None
# Circuit_Writer_Conductive_Silver_Ink                       None        None
# High_Performance_Fluid                                     None        None
# Deco_Art_Dazzling_Metallics_All_Colors                     None        None
# Energizer_Batteries                                        None        None
# Goo_Gone                                                   None        None
# Loctite_Clear_Silicone_Sealant                             None        None
# Loctite_Epoxy_Extra_Time_Resin                             None        None
# Loctite_Epoxy_Quickset_Part_A                              None        None
# Loctite_Threadlocker_Blue_242                       112945-52-5  13463-67-7
# Alkaline_Button_Cell_Battery_AG13                     1313-13-9   9004-34-6
# Atmospheres_HQ_Light_Enhancement_Fluid                     None        None
# Permatex_Clear_RTV_Silicone                                None        None
# Solid_Lead-Free_Alloy_Solder_Wire                          None        None
# Look_Solutions_Fog_Fluid_&_Haze_Fluid                      None        None
# Powerex_AA_Rechargeable_Batteries                     7440-02-0   1310-65-2
# MDG_Natural_Fluid                                          None        None
# Sharpie_Accent_Highlighters_All_Colors                     None        None
# Sharpie_Markers_All_Colors_and_Sizes                       None        None
# UniPaint_Markers_All_Colors_and_Sizes                      None        None
# Duracell_Alkaline_Batteries                                None        None
# Febreze_Set_&_Refresh_Rain                              97-54-1   8000-41-7
# Lysol_III_Disinfectant_Spray_All_Scents                    None        None
# Lithium_Ion_Battery_Cell_For_Use_With_Anton-Bau...    7429-90-5  12057-17-9
# Windex_Original_Glass_Cleaner                              None        None
# Nickel_Metal_Hydride_Batteries                        7440-02-0   1310-65-2
# Office_Depot_Compressed_Air_Duster                         None        None
# Set_XP_High_Strength_Epoxy_Adhesive                     90-72-2  68953-36-6
# Gorilla_Hot_Glue_Clear                                     None        None
# Gorilla_Super_Glue                                         None        None
# Sealed_Lead_Acid_Batteries                            9003-53-6   7440-31-5
# XT_Power_Lithium_Polymer_Battery                      7440-02-0  21340-40-3
# WD-40_Multi-Use_Product_Aerosol                      64742-53-6        None
# Goof_Off_2                                                 None        None
#
#                                                              8          9  \
# desktop                                                   None       None
# Ad-Tech_962_Black_Glue_Stick                              None       None
# Graphite_Powder_Extra_Fine                                None       None
# Lock Ease_Graphited_Lock_Fluid                         57-11-4   100-41-4
# Solder_Paste_Flux                                         None       None
# Circuit_Writer_Conductive_Silver_Ink                      None       None
# High_Performance_Fluid                                    None       None
# Deco_Art_Dazzling_Metallics_All_Colors                    None       None
# Energizer_Batteries                                       None       None
# Goo_Gone                                                  None       None
# Loctite_Clear_Silicone_Sealant                            None       None
# Loctite_Epoxy_Extra_Time_Resin                            None       None
# Loctite_Epoxy_Quickset_Part_A                             None       None
# Loctite_Threadlocker_Blue_242                        2018-01-1       None
# Alkaline_Button_Cell_Battery_AG13                         None       None
# Atmospheres_HQ_Light_Enhancement_Fluid                    None       None
# Permatex_Clear_RTV_Silicone                               None       None
# Solid_Lead-Free_Alloy_Solder_Wire                         None       None
# Look_Solutions_Fog_Fluid_&_Haze_Fluid                     None       None
# Powerex_AA_Rechargeable_Batteries                    7440-48-4  1333-86-4
# MDG_Natural_Fluid                                         None       None
# Sharpie_Accent_Highlighters_All_Colors                    None       None
# Sharpie_Markers_All_Colors_and_Sizes                      None       None
# UniPaint_Markers_All_Colors_and_Sizes                     None       None
# Duracell_Alkaline_Batteries                               None       None
# Febreze_Set_&_Refresh_Rain                          32210-23-4  5989-27-5
# Lysol_III_Disinfectant_Spray_All_Scents                   None       None
# Lithium_Ion_Battery_Cell_For_Use_With_Anton-Bau...   7440-50-8   799-23-3
# Windex_Original_Glass_Cleaner                             None       None
# Nickel_Metal_Hydride_Batteries                       7440-48-4  1333-86-4
# Office_Depot_Compressed_Air_Duster                        None       None
# Set_XP_High_Strength_Epoxy_Adhesive                    71-36-3    60-00-0
# Gorilla_Hot_Glue_Clear                                    None       None
# Gorilla_Super_Glue                                        None       None
# Sealed_Lead_Acid_Batteries                           9003-54-7  7440-36-0
# XT_Power_Lithium_Polymer_Battery                     1308-04-9       None
# WD-40_Multi-Use_Product_Aerosol                           None       None
# Goof_Off_2                                                None       None
#
#                                                     ...          20  \
# desktop                                             ...        None
# Ad-Tech_962_Black_Glue_Stick                        ...        None
# Graphite_Powder_Extra_Fine                          ...        None
# Lock Ease_Graphited_Lock_Fluid                      ...        None
# Solder_Paste_Flux                                   ...        None
# Circuit_Writer_Conductive_Silver_Ink                ...        None
# High_Performance_Fluid                              ...        None
# Deco_Art_Dazzling_Metallics_All_Colors              ...        None
# Energizer_Batteries                                 ...        None
# Goo_Gone                                            ...        None
# Loctite_Clear_Silicone_Sealant                      ...        None
# Loctite_Epoxy_Extra_Time_Resin                      ...        None
# Loctite_Epoxy_Quickset_Part_A                       ...        None
# Loctite_Threadlocker_Blue_242                       ...        None
# Alkaline_Button_Cell_Battery_AG13                   ...        None
# Atmospheres_HQ_Light_Enhancement_Fluid              ...        None
# Permatex_Clear_RTV_Silicone                         ...        None
# Solid_Lead-Free_Alloy_Solder_Wire                   ...        None
# Look_Solutions_Fog_Fluid_&_Haze_Fluid               ...        None
# Powerex_AA_Rechargeable_Batteries                   ...        None
# MDG_Natural_Fluid                                   ...        None
# Sharpie_Accent_Highlighters_All_Colors              ...        None
# Sharpie_Markers_All_Colors_and_Sizes                ...        None
# UniPaint_Markers_All_Colors_and_Sizes               ...        None
# Duracell_Alkaline_Batteries                         ...        None
# Febreze_Set_&_Refresh_Rain                          ...  68039-49-6
# Lysol_III_Disinfectant_Spray_All_Scents             ...        None
# Lithium_Ion_Battery_Cell_For_Use_With_Anton-Bau...  ...        None
# Windex_Original_Glass_Cleaner                       ...        None
# Nickel_Metal_Hydride_Batteries                      ...        None
# Office_Depot_Compressed_Air_Duster                  ...        None
# Set_XP_High_Strength_Epoxy_Adhesive                 ...        None
# Gorilla_Hot_Glue_Clear                              ...        None
# Gorilla_Super_Glue                                  ...        None
# Sealed_Lead_Acid_Batteries                          ...        None
# XT_Power_Lithium_Polymer_Battery                    ...        None
# WD-40_Multi-Use_Product_Aerosol                     ...        None
# Goof_Off_2                                          ...        None
#
#                                                             21        22  \
# desktop                                                   None      None
# Ad-Tech_962_Black_Glue_Stick                              None      None
# Graphite_Powder_Extra_Fine                                None      None
# Lock Ease_Graphited_Lock_Fluid                            None      None
# Solder_Paste_Flux                                         None      None
# Circuit_Writer_Conductive_Silver_Ink                      None      None
# High_Performance_Fluid                                    None      None
# Deco_Art_Dazzling_Metallics_All_Colors                    None      None
# Energizer_Batteries                                       None      None
# Goo_Gone                                                  None      None
# Loctite_Clear_Silicone_Sealant                            None      None
# Loctite_Epoxy_Extra_Time_Resin                            None      None
# Loctite_Epoxy_Quickset_Part_A                             None      None
# Loctite_Threadlocker_Blue_242                             None      None
# Alkaline_Button_Cell_Battery_AG13                         None      None
# Atmospheres_HQ_Light_Enhancement_Fluid                    None      None
# Permatex_Clear_RTV_Silicone                               None      None
# Solid_Lead-Free_Alloy_Solder_Wire                         None      None
# Look_Solutions_Fog_Fluid_&_Haze_Fluid                     None      None
# Powerex_AA_Rechargeable_Batteries                         None      None
# MDG_Natural_Fluid                                         None      None
# Sharpie_Accent_Highlighters_All_Colors                    None      None
# Sharpie_Markers_All_Colors_and_Sizes                      None      None
# UniPaint_Markers_All_Colors_and_Sizes                     None      None
# Duracell_Alkaline_Batteries                               None      None
# Febreze_Set_&_Refresh_Rain                          25265-71-8  112-31-2
# Lysol_III_Disinfectant_Spray_All_Scents                   None      None
# Lithium_Ion_Battery_Cell_For_Use_With_Anton-Bau...        None      None
# Windex_Original_Glass_Cleaner                             None      None
# Nickel_Metal_Hydride_Batteries                            None      None
# Office_Depot_Compressed_Air_Duster                        None      None
# Set_XP_High_Strength_Epoxy_Adhesive                       None      None
# Gorilla_Hot_Glue_Clear                                    None      None
# Gorilla_Super_Glue                                        None      None
# Sealed_Lead_Acid_Batteries                                None      None
# XT_Power_Lithium_Polymer_Battery                          None      None
# WD-40_Multi-Use_Product_Aerosol                           None      None
# Goof_Off_2                                                None      None
#
#                                                           23       24  \
# desktop                                                 None     None
# Ad-Tech_962_Black_Glue_Stick                            None     None
# Graphite_Powder_Extra_Fine                              None     None
# Lock Ease_Graphited_Lock_Fluid                          None     None
# Solder_Paste_Flux                                       None     None
# Circuit_Writer_Conductive_Silver_Ink                    None     None
# High_Performance_Fluid                                  None     None
# Deco_Art_Dazzling_Metallics_All_Colors                  None     None
# Energizer_Batteries                                     None     None
# Goo_Gone                                                None     None
# Loctite_Clear_Silicone_Sealant                          None     None
# Loctite_Epoxy_Extra_Time_Resin                          None     None
# Loctite_Epoxy_Quickset_Part_A                           None     None
# Loctite_Threadlocker_Blue_242                           None     None
# Alkaline_Button_Cell_Battery_AG13                       None     None
# Atmospheres_HQ_Light_Enhancement_Fluid                  None     None
# Permatex_Clear_RTV_Silicone                             None     None
# Solid_Lead-Free_Alloy_Solder_Wire                       None     None
# Look_Solutions_Fog_Fluid_&_Haze_Fluid                   None     None
# Powerex_AA_Rechargeable_Batteries                       None     None
# MDG_Natural_Fluid                                       None     None
# Sharpie_Accent_Highlighters_All_Colors                  None     None
# Sharpie_Markers_All_Colors_and_Sizes                    None     None
# UniPaint_Markers_All_Colors_and_Sizes                   None     None
# Duracell_Alkaline_Batteries                             None     None
# Febreze_Set_&_Refresh_Rain                          142-19-8  78-70-6
# Lysol_III_Disinfectant_Spray_All_Scents                 None     None
# Lithium_Ion_Battery_Cell_For_Use_With_Anton-Bau...      None     None
# Windex_Original_Glass_Cleaner                           None     None
# Nickel_Metal_Hydride_Batteries                          None     None
# Office_Depot_Compressed_Air_Duster                      None     None
# Set_XP_High_Strength_Epoxy_Adhesive                     None     None
# Gorilla_Hot_Glue_Clear                                  None     None
# Gorilla_Super_Glue                                      None     None
# Sealed_Lead_Acid_Batteries                              None     None
# XT_Power_Lithium_Polymer_Battery                        None     None
# WD-40_Multi-Use_Product_Aerosol                         None     None
# Goof_Off_2                                              None     None
#
#                                                           25        26  \
# desktop                                                 None      None
# Ad-Tech_962_Black_Glue_Stick                            None      None
# Graphite_Powder_Extra_Fine                              None      None
# Lock Ease_Graphited_Lock_Fluid                          None      None
# Solder_Paste_Flux                                       None      None
# Circuit_Writer_Conductive_Silver_Ink                    None      None
# High_Performance_Fluid                                  None      None
# Deco_Art_Dazzling_Metallics_All_Colors                  None      None
# Energizer_Batteries                                     None      None
# Goo_Gone                                                None      None
# Loctite_Clear_Silicone_Sealant                          None      None
# Loctite_Epoxy_Extra_Time_Resin                          None      None
# Loctite_Epoxy_Quickset_Part_A                           None      None
# Loctite_Threadlocker_Blue_242                           None      None
# Alkaline_Button_Cell_Battery_AG13                       None      None
# Atmospheres_HQ_Light_Enhancement_Fluid                  None      None
# Permatex_Clear_RTV_Silicone                             None      None
# Solid_Lead-Free_Alloy_Solder_Wire                       None      None
# Look_Solutions_Fog_Fluid_&_Haze_Fluid                   None      None
# Powerex_AA_Rechargeable_Batteries                       None      None
# MDG_Natural_Fluid                                       None      None
# Sharpie_Accent_Highlighters_All_Colors                  None      None
# Sharpie_Markers_All_Colors_and_Sizes                    None      None
# UniPaint_Markers_All_Colors_and_Sizes                   None      None
# Duracell_Alkaline_Batteries                             None      None
# Febreze_Set_&_Refresh_Rain                          106-25-2  115-95-7
# Lysol_III_Disinfectant_Spray_All_Scents                 None      None
# Lithium_Ion_Battery_Cell_For_Use_With_Anton-Bau...      None      None
# Windex_Original_Glass_Cleaner                           None      None
# Nickel_Metal_Hydride_Batteries                          None      None
# Office_Depot_Compressed_Air_Duster                      None      None
# Set_XP_High_Strength_Epoxy_Adhesive                     None      None
# Gorilla_Hot_Glue_Clear                                  None      None
# Gorilla_Super_Glue                                      None      None
# Sealed_Lead_Acid_Batteries                              None      None
# XT_Power_Lithium_Polymer_Battery                        None      None
# WD-40_Multi-Use_Product_Aerosol                         None      None
# Goof_Off_2                                              None      None
#
#                                                           27       28  \
# desktop                                                 None     None
# Ad-Tech_962_Black_Glue_Stick                            None     None
# Graphite_Powder_Extra_Fine                              None     None
# Lock Ease_Graphited_Lock_Fluid                          None     None
# Solder_Paste_Flux                                       None     None
# Circuit_Writer_Conductive_Silver_Ink                    None     None
# High_Performance_Fluid                                  None     None
# Deco_Art_Dazzling_Metallics_All_Colors                  None     None
# Energizer_Batteries                                     None     None
# Goo_Gone                                                None     None
# Loctite_Clear_Silicone_Sealant                          None     None
# Loctite_Epoxy_Extra_Time_Resin                          None     None
# Loctite_Epoxy_Quickset_Part_A                           None     None
# Loctite_Threadlocker_Blue_242                           None     None
# Alkaline_Button_Cell_Battery_AG13                       None     None
# Atmospheres_HQ_Light_Enhancement_Fluid                  None     None
# Permatex_Clear_RTV_Silicone                             None     None
# Solid_Lead-Free_Alloy_Solder_Wire                       None     None
# Look_Solutions_Fog_Fluid_&_Haze_Fluid                   None     None
# Powerex_AA_Rechargeable_Batteries                       None     None
# MDG_Natural_Fluid                                       None     None
# Sharpie_Accent_Highlighters_All_Colors                  None     None
# Sharpie_Markers_All_Colors_and_Sizes                    None     None
# UniPaint_Markers_All_Colors_and_Sizes                   None     None
# Duracell_Alkaline_Batteries                             None     None
# Febreze_Set_&_Refresh_Rain                          101-84-8  97-53-0
# Lysol_III_Disinfectant_Spray_All_Scents                 None     None
# Lithium_Ion_Battery_Cell_For_Use_With_Anton-Bau...      None     None
# Windex_Original_Glass_Cleaner                           None     None
# Nickel_Metal_Hydride_Batteries                          None     None
# Office_Depot_Compressed_Air_Duster                      None     None
# Set_XP_High_Strength_Epoxy_Adhesive                     None     None
# Gorilla_Hot_Glue_Clear                                  None     None
# Gorilla_Super_Glue                                      None     None
# Sealed_Lead_Acid_Batteries                              None     None
# XT_Power_Lithium_Polymer_Battery                        None     None
# WD-40_Multi-Use_Product_Aerosol                         None     None
# Goof_Off_2                                              None     None
#
#                                                                                           CAS Numbers
# desktop
# Ad-Tech_962_Black_Glue_Stick                                        24937-78-8, 9002-88-4, 64742-16-1
# Graphite_Powder_Extra_Fine
# Lock Ease_Graphited_Lock_Fluid                      71-43-2, 64742-82-1, 91-20-3, 2057-10-0, 8052-...
# Solder_Paste_Flux
# Circuit_Writer_Conductive_Silver_Ink                                    106-65-0, 627-93-0, 1119-40-0
# High_Performance_Fluid
# Deco_Art_Dazzling_Metallics_All_Colors                                57-55-6, 12001-26-2, 28205-96-1
# Energizer_Batteries                                       7440-66-6, 1310-58-3, 65997-19-5, 1313-13-9
# Goo_Gone                                                                        64742-47-8, 5989-27-5
# Loctite_Clear_Silicone_Sealant                      17689-77-9, 7631-86-9, 4253-34-3, 64742-46-7, ...
# Loctite_Epoxy_Extra_Time_Resin
# Loctite_Epoxy_Quickset_Part_A
# Loctite_Threadlocker_Blue_242                       57-55-6, 80-15-9, 98-82-8, 9004-96-0, 2081-07-...
# Alkaline_Button_Cell_Battery_AG13                   2015-07-1, 7732-18-5, 9003-53-6, 1310-58-3, 74...
# Atmospheres_HQ_Light_Enhancement_Fluid                                                       112-27-6
# Permatex_Clear_RTV_Silicone
# Solid_Lead-Free_Alloy_Solder_Wire                          7440-22-4, 7440-50-8, 7440-31-5, 7440-36-0
# Look_Solutions_Fog_Fluid_&_Haze_Fluid                                    7732-18-5, 57-55-6, 112-27-6
# Powerex_AA_Rechargeable_Batteries                   7439-96-5, 7429-90-5, 1310-73-2, 1310-58-3, 74...
# MDG_Natural_Fluid                                                                           8042-47-5
# Sharpie_Accent_Highlighters_All_Colors                                   57-55-6, 25322-68-3, 56-81-5
# Sharpie_Markers_All_Colors_and_Sizes                                       123-42-2, 64-17-5, 71-23-8
# UniPaint_Markers_All_Colors_and_Sizes                                   1330-20-7, 78-83-1, 7440-66-6
# Duracell_Alkaline_Batteries                         7440-66-6, 41-58-0, 7440-44-0, 1310-58-3, 1313...
# Febreze_Set_&_Refresh_Rain                          57378-68-4, 2060-12-0, 476332-65-7, 112-45-8, ...
# Lysol_III_Disinfectant_Spray_All_Scents                                   777-99-6, 64-17-5, 106-97-8
# Lithium_Ion_Battery_Cell_For_Use_With_Anton-Bau...  182442-95-1, 799-24-4, 799-23-2, 12190-79-3, 7...
# Windex_Original_Glass_Cleaner
# Nickel_Metal_Hydride_Batteries                      7439-96-5, 7429-90-5, 1310-73-2, 1310-58-3, 74...
# Office_Depot_Compressed_Air_Duster
# Set_XP_High_Strength_Epoxy_Adhesive                 1344-28-1, 2426-08-0, 69-00-0, 74-00-8, 39-00-...
# Gorilla_Hot_Glue_Clear
# Gorilla_Super_Glue
# Sealed_Lead_Acid_Batteries                          7440-38-2, 9003-56-9, 7664-93-9, 7439-92-1, 90...
# XT_Power_Lithium_Polymer_Battery                    24937-79-9, 9003-07-0, 7440-50-8, 133-86-4, 74...
# WD-40_Multi-Use_Product_Aerosol                     64742-65-0, 124-38-9, 64742-47-8, 64742-56-9, ...
# Goof_Off_2                                                               770-35-4, 100-51-6, 112-34-5
#
# [38 rows x 30 columns]

# %%
# Remove all columns except combined CAS number column
sds_dataframe.drop(sds_dataframe.columns[0:29], axis = 1, inplace = True)

# %%
sds_dataframe
# Out:
#                                                                                           CAS Numbers
# desktop
# Ad-Tech_962_Black_Glue_Stick                                        24937-78-8, 9002-88-4, 64742-16-1
# Graphite_Powder_Extra_Fine
# Lock Ease_Graphited_Lock_Fluid                      71-43-2, 64742-82-1, 91-20-3, 2057-10-0, 8052-...
# Solder_Paste_Flux
# Circuit_Writer_Conductive_Silver_Ink                                    106-65-0, 627-93-0, 1119-40-0
# High_Performance_Fluid
# Deco_Art_Dazzling_Metallics_All_Colors                                57-55-6, 12001-26-2, 28205-96-1
# Energizer_Batteries                                       7440-66-6, 1310-58-3, 65997-19-5, 1313-13-9
# Goo_Gone                                                                        64742-47-8, 5989-27-5
# Loctite_Clear_Silicone_Sealant                      17689-77-9, 7631-86-9, 4253-34-3, 64742-46-7, ...
# Loctite_Epoxy_Extra_Time_Resin
# Loctite_Epoxy_Quickset_Part_A
# Loctite_Threadlocker_Blue_242                       57-55-6, 80-15-9, 98-82-8, 9004-96-0, 2081-07-...
# Alkaline_Button_Cell_Battery_AG13                   2015-07-1, 7732-18-5, 9003-53-6, 1310-58-3, 74...
# Atmospheres_HQ_Light_Enhancement_Fluid                                                       112-27-6
# Permatex_Clear_RTV_Silicone
# Solid_Lead-Free_Alloy_Solder_Wire                          7440-22-4, 7440-50-8, 7440-31-5, 7440-36-0
# Look_Solutions_Fog_Fluid_&_Haze_Fluid                                    7732-18-5, 57-55-6, 112-27-6
# Powerex_AA_Rechargeable_Batteries                   7439-96-5, 7429-90-5, 1310-73-2, 1310-58-3, 74...
# MDG_Natural_Fluid                                                                           8042-47-5
# Sharpie_Accent_Highlighters_All_Colors                                   57-55-6, 25322-68-3, 56-81-5
# Sharpie_Markers_All_Colors_and_Sizes                                       123-42-2, 64-17-5, 71-23-8
# UniPaint_Markers_All_Colors_and_Sizes                                   1330-20-7, 78-83-1, 7440-66-6
# Duracell_Alkaline_Batteries                         7440-66-6, 41-58-0, 7440-44-0, 1310-58-3, 1313...
# Febreze_Set_&_Refresh_Rain                          57378-68-4, 2060-12-0, 476332-65-7, 112-45-8, ...
# Lysol_III_Disinfectant_Spray_All_Scents                                   777-99-6, 64-17-5, 106-97-8
# Lithium_Ion_Battery_Cell_For_Use_With_Anton-Bau...  182442-95-1, 799-24-4, 799-23-2, 12190-79-3, 7...
# Windex_Original_Glass_Cleaner
# Nickel_Metal_Hydride_Batteries                      7439-96-5, 7429-90-5, 1310-73-2, 1310-58-3, 74...
# Office_Depot_Compressed_Air_Duster
# Set_XP_High_Strength_Epoxy_Adhesive                 1344-28-1, 2426-08-0, 69-00-0, 74-00-8, 39-00-...
# Gorilla_Hot_Glue_Clear
# Gorilla_Super_Glue
# Sealed_Lead_Acid_Batteries                          7440-38-2, 9003-56-9, 7664-93-9, 7439-92-1, 90...
# XT_Power_Lithium_Polymer_Battery                    24937-79-9, 9003-07-0, 7440-50-8, 133-86-4, 74...
# WD-40_Multi-Use_Product_Aerosol                     64742-65-0, 124-38-9, 64742-47-8, 64742-56-9, ...
# Goof_Off_2                                                               770-35-4, 100-51-6, 112-34-5

# %%
sds_dataframe['Manufacturer'] = manufacturer
sds_dataframe = sds_dataframe.reset_index()

# %%
sds_dataframe.rename(columns={'index':'Product'}, inplace=True)

# %%
sds_dataframe = sds_dataframe[['Manufacturer', 'Product', 'CAS Numbers']]

# %%
sds_dataframe.replace('_', ' ', regex=True, inplace=True)

# %%
# Replace empty cells with NaN values
sds_dataframe['CAS Numbers'].replace('', np.nan, inplace=True)

# %%
# Drop rows of products with no CAS numbers
sds_dataframe = sds_dataframe.dropna(axis=0, subset=['CAS Numbers'])

# %%
sds_dataframe.insert(loc=2, column="Max Quantity", value=1)

# %%
sds_dataframe.insert(loc=4, column="Added", value='X')

# %%
sds_dataframe.insert(loc=5, column="Deleted", value='')

# %%
# Finished spreadsheet
sds_dataframe.head(10)
# Out:
#                        Manufacturer                                 Product  \
# 1         Adhesive Technologies Inc            Ad-Tech 962 Black Glue Stick
# 3                       AGS Company          Lock Ease Graphited Lock Fluid
# 5                 CAIG Laboratories    Circuit Writer Conductive Silver Ink
# 7                           DecoArt  Deco Art Dazzling Metallics All Colors
# 8   Energizer Battery Manufacturing                     Energizer Batteries
# 9                          Goo Gone                                Goo Gone
# 10               Henkel Corporation          Loctite Clear Silicone Sealant
# 13               Henkel Corporation           Loctite Threadlocker Blue 242
# 14      HI-Watt Battery Industry Co       Alkaline Button Cell Battery AG13
# 15                 High End Systems  Atmospheres HQ Light Enhancement Fluid
#
#     Max Quantity                                        CAS Numbers Added  \
# 1              1                  24937-78-8, 9002-88-4, 64742-16-1     X
# 3              1  71-43-2, 64742-82-1, 91-20-3, 2057-10-0, 8052-...     X
# 5              1                      106-65-0, 627-93-0, 1119-40-0     X
# 7              1                    57-55-6, 12001-26-2, 28205-96-1     X
# 8              1        7440-66-6, 1310-58-3, 65997-19-5, 1313-13-9     X
# 9              1                              64742-47-8, 5989-27-5     X
# 10             1  17689-77-9, 7631-86-9, 4253-34-3, 64742-46-7, ...     X
# 13             1  57-55-6, 80-15-9, 98-82-8, 9004-96-0, 2081-07-...     X
# 14             1  2015-07-1, 7732-18-5, 9003-53-6, 1310-58-3, 74...     X
# 15             1                                           112-27-6     X
#
#    Deleted
# 1
# 3
# 5
# 7
# 8
# 9
# 10
# 13
# 14
# 15

# %%
sds_dataframe.to_excel("WirtzLight_Shop_SDS_Inventory.xlsx", index=False)
